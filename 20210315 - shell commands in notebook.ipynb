# %%
from tqdm.notebook import tqdm, trange

# %cd /home/jdowzell/Documents/university/Thesis/Workbooks
# %cd SIM_DATA
# %cd unpacked
# %cd tst
# Out:
# /home/jdowzell/Documents/university/Thesis/Workbooks
# /home/jdowzell/Documents/university/Thesis/Workbooks/SIM_DATA
# /home/jdowzell/Documents/university/Thesis/Workbooks/SIM_DATA/unpacked
# /home/jdowzell/Documents/university/Thesis/Workbooks/SIM_DATA/unpacked/tst

# %%
# !for f in *.gz; do echo "$f"; gzip -d "$f"; done
# Out:
# tess2018191215100-s0001-0000000031108321-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031108599-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031160873-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031163372-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031165050-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031166048-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031166437-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031168683-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031177972-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031181554-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031229523-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031230943-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031231707-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031232347-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031232945-0001-a_lc.fits.gz
# tess2018191215100-s0001-0000000031235017-0001-a_lc.fits.gz
# ...

# %% [markdown]
# This code extracts all my files from their gz compression and deletes the compressed file afterwards.
# I still want to move them all into a previous directory, but I did that in actual shell rather than here for ease.
